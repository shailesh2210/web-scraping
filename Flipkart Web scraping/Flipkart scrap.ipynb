# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
product_name = []
price = []
description = []
review = []

for i in range(2 , 100):
    url = "https://www.flipkart.com/search?q=mobiles+under+60000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&page=1"+str(i)
    r = requests.get(url)
    
    soup = BeautifulSoup(r.text , "lxml")
    box = soup.find("div" , "_1YokD2 _3Mn1Gg")
    
    names = box.find_all("div" , class_ = "_4rR01T")
    for i in names:
        name = i.text
        product_name.append(name)
    
    prices = box.find_all("div" , class_ = "_30jeq3 _1_WHN1")
    for i in prices:
        pri = i.text
        price.append(pri)
        
    desc = box.find_all("ul" , class_ = "_1xgFaf")
    for i in desc:
        name = i.text
        description.append(name)
        
    rev = box.find_all("div", class_="_3LWZlK")
    for i in rev:
        r = i.text
        review.append(r)

# %%
print(len(product_name))
print(len(price))
print(len(description))
print(len(review))
# Out:
# 192
# 192
# 192
# 188

# %%
data = pd.DataFrame({"product_name": product_name , "price":price , "description":description})

# %%
data
# Out:
#                                     product_name    price  \
# 0      Infinix HOT 20 Play (Racing Black, 64 GB)   ₹7,999
# 1                  REDMI A1+ (Light Blue, 32 GB)   ₹6,299
# 2    SAMSUNG Galaxy S22 Ultra 5G (Green, 256 GB)  ₹83,999
# 3                 Kechaoda K66 The Music House 4   ₹1,195
# 4                               KARBONN Jumbo K9   ₹1,289
# ..                                           ...      ...
# 187                              Good One G5605N     ₹999
# 188                      Nokia TA-1174 / TA-1299   ₹1,635
# 189                                Kechaoda K115   ₹1,120
# 190                                Kechaoda K115   ₹1,118
# 191                                 Kechaoda K90   ₹1,510
#
#                                            description
# 0    4 GB RAM | 64 GB ROM | Expandable Upto 256 GB1...
# 1    2 GB RAM | 32 GB ROM | Expandable Upto 512 GB1...
# 2    12 GB RAM | 256 GB ROM17.27 cm (6.8 inch) Quad...
# ...
